# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

df = pd.read_csv("dt.csv")
my_players_set = ('R Laird', 'J Sicily', 'S Murray', 'J Finlayson', 
                   'I Cumming', 'N Coffield', 'A Pearce', 'A Naughton', 
                  'J McCrae', 'T Mitchell', 'N Fyfe', 'S Coniglio', 'P Dangerfield', 
                  'D Martin', 'Z Merrett', 'T Kelly', 'E Phillips', 'K Mutch', 'M Gawn', 
                  'S Martin', 'B Crossley', 'D Cameron', 'T McLean', 'I Heeney', 'S Menegola', 
                   'D Smith', 'B Fritsch', 'J Waterman', 'L Keeffe', 'C Rayner')
my_players_df = df.loc[df['player'].isin(my_players_set)]
scores_only = my_players_df.drop(['position', 'start_price', 'current_price', 'own', 'games','be'], axis=1)
scores_only_T = scores_only.set_index('player').T
# Out:
# player   P Dangerfield  R Laird  S Martin  L Keeffe  N Fyfe  S Menegola  \
# round_1            NaN    124.0      94.0       NaN    67.0        69.0
# round_2          118.0    141.0      68.0       NaN   123.0        50.0
# round_3          102.0    120.0     177.0       NaN   144.0       120.0
# round_4           97.0    115.0     101.0       NaN    91.0       118.0
# round_5          109.0     89.0      99.0       NaN   136.0       103.0
# round_6           70.0    114.0      92.0       NaN   101.0        88.0
# round_7          109.0    100.0     130.0      76.0   128.0        65.0
# round_8          106.0     83.0     113.0      49.0   106.0       121.0
# round_9          105.0    102.0      96.0      41.0    97.0        71.0
#
# player   S Coniglio  D Smith  M Gawn  D Martin     ...      K Mutch  \
# round_1       146.0     91.0   138.0     110.0     ...          NaN
# round_2       120.0    115.0    78.0     127.0     ...          NaN
# round_3       111.0     72.0   114.0      67.0     ...          NaN
# round_4       121.0     91.0   127.0     111.0     ...          NaN
# round_5       112.0     91.0   143.0      73.0     ...          NaN
# round_6       102.0    101.0   135.0     101.0     ...         71.0
# round_7        92.0     94.0   111.0      93.0     ...         66.0
# round_8       111.0    117.0   111.0      48.0     ...         43.0
# round_9        92.0     96.0   105.0      73.0     ...          NaN
#
# player   I Cumming  E Phillips  J Waterman  C Rayner  B Crossley  T Kelly  \
# round_1        NaN         NaN        44.0      35.0         NaN     81.0
# round_2        NaN         NaN        54.0      24.0         NaN    115.0
# round_3        NaN         NaN        96.0      52.0         NaN     79.0
# round_4        NaN         NaN        47.0      85.0         NaN     63.0
# round_5        NaN         NaN        49.0      42.0         NaN     70.0
# round_6        NaN         NaN        77.0      52.0         NaN     82.0
# round_7        NaN         NaN        48.0      63.0        69.0     92.0
# round_8       52.0        86.0        67.0      35.0        44.0     65.0
# round_9       22.0        56.0        48.0      58.0        29.0     64.0
#
# player   B Fritsch  N Coffield  A Naughton
# round_1       74.0         NaN        41.0
# round_2       60.0         NaN        61.0
# round_3       47.0        73.0        49.0
# round_4       47.0        69.0        62.0
# round_5        NaN        79.0        53.0
# round_6       88.0        21.0        67.0
# round_7       91.0        70.0        63.0
# round_8       89.0        61.0         3.0
# round_9       96.0        47.0         NaN
#
# [9 rows x 28 columns]

# %%
sns.boxplot(x="player", y="value", data=pd.melt(scores_only_T))
plt.show()

# %%
my_players_df.to_csv("my_players.csv", columns=['player','round_1', 'round_2', 'round_3', 'round_4', 'round_5', 'round_6', 'round_7', 'round_8', 'round_9'], index=False)
