# %%
import pandas as pd
df = pd.read_csv("dt.csv")
df
# Out:
#                player position  start_price  current_price   own  games  \
# 0            R Atkins      Mid     572000.0       598000.0   1.2    8.0
# 1             L Brown      Def     412000.0       494000.0   0.5    8.0
# 2       P Dangerfield      Mid     849000.0       703000.0  19.2    7.0
# 3           R Douglas      Mid     570000.0       579000.0   0.4    7.0
# 4      C Ellis-Yolmen      Mid     389000.0       583000.0   4.8    8.0
# 5          K Hartigan      Def     318000.0       329000.0   1.5    5.0
# 6         R Henderson      Mid     615000.0       619000.0   0.1    7.0
# 7            S Jacobs      Ruc     700000.0       603000.0  12.4    8.0
# 8           J Jenkins      Fwd     572000.0       474000.0   1.3    8.0
# 9          S Kerridge      Mid     592000.0       584000.0   0.1    4.0
# 10            R Laird      Def     707000.0       729000.0  69.7    8.0
# 11         T T. Lynch      Fwd     640000.0       594000.0   1.8    6.0
# ...

# %%
df.columns
# Out:
# Index(['player', 'position', 'start_price', 'current_price', 'own', 'games',
#        'be', 'round_1', 'round_2', 'round_3', 'round_4', 'round_5', 'round_6',
#        'round_7', 'round_8'],
#       dtype='object')

# %%
df.to_csv("dt_scores.csv", columns=['player','round_1', 'round_2', 'round_3', 'round_4', 'round_5', 'round_6', 'round_7', 'round_8'], index=False)
