# %%
import pandas as pd
df = pd.read_csv("dt.csv")
my_players_set = ('R Laird', 'J Sicily', 'S Murray', 'J Finlayson', 
                   'I Cumming', 'N Coffield', 'A Pearce', 'A Naughton', 
                  'J McCrae', 'T Mitchell', 'N Fyfe', 'S Coniglio', 'P Dangerfield', 
                  'D Martin', 'Z Merrett', 'T Kelly', 'E Phillips', 'K Mutch', 'M Gawn', 
                  'S Martin', 'B Crossley', 'D Cameron', 'T McLean', 'I Heeney', 'S Menegola', 
                   'D Smith', 'B Fritsch', 'J Waterman', 'L Keeffe', 'C Rayner')
my_players_df = df.loc[df['player'].isin(my_players_set)]
my_players_df
# Out:
#             player position  start_price  current_price   own  games     be  \
# 2    P Dangerfield      Mid     849000.0       695000.0  20.6    8.0  111.0
# 10         R Laird      Def     707000.0       708000.0  70.2    9.0  129.0
# 28        S Martin      Ruc     703000.0       730000.0  20.1    9.0  118.0
# 57        L Keeffe  Def,Fwd     170000.0       253000.0  22.8    3.0   15.0
# 86          N Fyfe      Mid     686000.0       751000.0  35.0    9.0  130.0
# 90      S Menegola  Mid,Fwd     719000.0       630000.0  18.4    9.0  115.0
# 141     S Coniglio      Mid     663000.0       719000.0  31.6    9.0  129.0
# 155        D Smith  Fwd,Mid     575000.0       646000.0  29.6    9.0   90.0
# 189         M Gawn      Ruc     605000.0       785000.0  51.6    9.0  135.0
# 241       D Martin      Mid     800000.0       601000.0  43.3    9.0  129.0
# 270     T Mitchell      Mid     896000.0       779000.0  70.0    9.0  123.0
# ...

# %%
df.columns
# Out:
# Index(['player', 'position', 'start_price', 'current_price', 'own', 'games',
#        'be', 'round_1', 'round_2', 'round_3', 'round_4', 'round_5', 'round_6',
#        'round_7', 'round_8'],
#       dtype='object')

# %%
my_players_df.to_csv("my_players.csv", columns=['player','round_1', 'round_2', 'round_3', 'round_4', 'round_5', 'round_6', 'round_7', 'round_8', 'round_9'], index=False)
